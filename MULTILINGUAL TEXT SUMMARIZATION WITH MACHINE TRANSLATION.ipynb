# %%
# !pip install nltk

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install googletrans==4.0.0-rc1
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 17.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 9.6 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-4.0.0rc1-py3-none-any.whl size=17396 sha256=4c28b619208536debc4da9e3c7bb697c03a80a922ad0804e756b0465bb67cf38
#   Stored in directory: /root/.cache/pip/wheels/c0/59/9f/7372f0cf70160fe61b528532e1a7c8498c4becd6bcffb022de
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
pip install gtts

# %%
pip install pydub

# %%
pip install play
# Out:
# ERROR: Could not find a version that satisfies the requirement play (from versions: 0-develop-1-gd67cd85)
# ERROR: No matching distribution found for play

# %%
# Provide your input text here
text =input()

# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text)

# Creating a frequency table to keep the score of each word
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] += 1
    else:
        freqTable[word] = 1

# Creating a dictionary to keep the score of each sentence
sentences = sent_tokenize(text)
sentenceValue = dict()

for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] += freq
            else:
                sentenceValue[sentence] = freq

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text
average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
        summary += " " + sentence
print("the summarized text is : ")
print(summary)
# Out:
# He is the captain of Chennai Super Kings (CSK) franchise in the Indian Premier League (IPL), leading them to the final on 10 occasions and winning in the 2010, 2011, 2018, 2021 and 2023 editions of the league, as well as winning the Champions League T20 two times, in 2010 and 2014. He is the 7th cricketer have scored more than 5,000 runs in the IPL, as well as being the first wicket-keeper to do so.  Dhoni received India's highest sport award, the Major Dhyanchand Khel Ratna Award in 2008, for his extraordinary performance at the international level in the sport and the Government of India bestowed him by country's fourth highest civilian award Padma Shri in 2009 and third highest civilian award Padma Bhushan in 2018. He is the only cricket captain in the world to win all three of the major ICC trophies, under his captaincy India won the 2011 ICC World Cup, the 2007 T20I World Cup and the 2013 ICC champions trophy. Dhoni holds an honorary rank of Lieutenant Colonel in the Parachute R
# ...

# %%
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

reference_summary = text
generated_summary = summary

# Tokenize the reference and generated summaries
reference_tokens = reference_summary.split()
generated_tokens = generated_summary.split()

# Compute BLEU score
bleu_score = sentence_bleu([reference_tokens], generated_tokens, smoothing_function=SmoothingFunction().method4)
print("BLEU Score:", bleu_score)
# Out:
# BLEU Score: 0.45303899669500136

# %%
from googletrans import Translator

# Initialize the translator
translator = Translator()

# Input text
input_text = summary

# Specify the source and target languages
source_language = 'en'  # English
target_language = input()  # French

# Translate the text
translated_text = translator.translate(input_text, src=source_language, dest=target_language)

# Print the translated text
print("Translated text:", translated_text.text)
# Out:
# te
# Translated text: అతను ఇండియన్ ప్రీమియర్ లీగ్ (ఐపిఎల్) లో చెన్నై సూపర్ కింగ్స్ (సిఎస్‌కె) ఫ్రాంచైజ్ కెప్టెన్, వాటిని 10 సందర్భాలలో ఫైనల్‌కు నడిపించాడు మరియు 2010, 2011, 2018, 2021 మరియు 2023 ఎడిషన్లలో లీగ్, అలాగే2010 మరియు 2014 లో ఛాంపియన్స్ లీగ్ టి 20 ను రెండుసార్లు గెలుచుకుంది. 2008 లో ధోని భారతదేశం యొక్క అత్యున్నత క్రీడా పురస్కారాన్ని అందుకుంది, క్రీడలో అంతర్జాతీయ స్థాయిలో మరియు భారత ప్రభుత్వం అతనికి దేశంలోని నాల్గవ స్థానంలో నిలిచింది.2009 లో అత్యధిక పౌర అవార్డు పద్మ శ్రీ మరియు 2018 లో మూడవ అత్యధిక పౌర అవార్డు పద్మ భూషణ్.

# %%
reference_translation = text
generated_translation = translated_text.text  # This is your generated translation

# Tokenize the reference and generated translations
reference_tokens = reference_translation.split()
generated_tokens = generated_translation.split()

# Compute BLEU score
bleu_score = sentence_bleu([reference_tokens], generated_tokens, smoothing_function=SmoothingFunction().method4)
print("BLEU Score for Translation:", bleu_score)
# Out:
# BLEU Score for Translation: 0.007437103148427303

# %%
from gtts import gTTS
from IPython.display import Audio

# Text to convert to speech
text = summary

# Language code for the target language
target_language = 'en'  # Replace with the appropriate language code

# Create a gTTS object with the target language
tts = gTTS(text, lang=target_language)

# Save the speech as a .wav file
tts.save('output.wav')

# Play the generated audio
sound_file = 'output.wav'
Audio(sound_file, autoplay=True)

# %%
from gtts import gTTS
from IPython.display import Audio
from googletrans import Translator

# Text to translate
text_to_translate = summary

# Language code for the source and target languages
source_language = 'en'  # English
target_language = input()  # Telugu

# Initialize the translator
translator = Translator()

# Translate the text
translated = translator.translate(text_to_translate, src=source_language, dest=target_language)

# Get the translated text as a string
translated_text = translated.text

# Create a gTTS object with the translated text
tts = gTTS(translated_text, lang=target_language)

# Save the speech as a .wav file
tts.save('output_telugu.wav')

# Play the generated audio
sound_file = 'output_telugu.wav'
Audio(sound_file, autoplay=True)

# %%
# !pip install nltk
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# !pip install googletrans==4.0.0-rc1
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
from googletrans import Translator
from gtts import gTTS
from IPython.display import Audio
from nltk.translate.bleu_score import sentence_bleu
from nltk.translate.bleu_score import SmoothingFunction

# Provide your input text here
text = input("Enter your input text: ")

# Tokenizing the text
stopWords = set(stopwords.words("english"))
words = word_tokenize(text)

# Creating a frequency table to keep the score of each word
freqTable = dict()
for word in words:
    word = word.lower()
    if word in stopWords:
        continue
    if word in freqTable:
        freqTable[word] += 1
    else:
        freqTable[word] = 1

# Creating a dictionary to keep the score of each sentence
sentences = sent_tokenize(text)
sentenceValue = dict()

for sentence in sentences:
    for word, freq in freqTable.items():
        if word in sentence.lower():
            if sentence in sentenceValue:
                sentenceValue[sentence] += freq
            else:
                sentenceValue[sentence] = freq

sumValues = 0
for sentence in sentenceValue:
    sumValues += sentenceValue[sentence]

# Average value of a sentence from the original text
average = int(sumValues / len(sentenceValue))

# Storing sentences into our summary.
summary = ''
for sentence in sentences:
    if (sentence in sentenceValue) and (sentenceValue[sentence] > (1.2 * average)):
        summary += " " + sentence

print("The summarized text is:")
print(summary)

# Initialize the translator
translator = Translator()

# Input text
input_text = summary

# Specify the source and target languages
source_language = 'en'  # English
target_language = input("Enter your target language (e.g., 'fr' for French): ")

# Translate the text
translated_text = translator.translate(input_text, src=source_language, dest=target_language)

# Print the translated text
print("Translated text:", translated_text.text)

# Evaluation with BLEU Score
reference_translation = text  # Replace with the actual reference translation text

# Tokenize the reference and generated translations
reference_tokens = reference_translation.split()
generated_tokens = translated_text.text.split()

# Compute BLEU score
bleu_score = sentence_bleu([reference_tokens], generated_tokens, smoothing_function=SmoothingFunction().method4)
print("BLEU Score for Translation:", bleu_score)

# Text to convert to speech
text = summary

# Language code for the target language
target_language = 'en'  # Replace with the appropriate language code

# Create a gTTS object with the target language
tts = gTTS(text, lang=target_language)

# Save the speech as a .wav file
tts.save('output.wav')

# Play the generated audio
sound_file = 'output.wav'
Audio(sound_file, autoplay=True)
# Out:
# ...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...
